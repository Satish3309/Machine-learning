# %%
import pickle 
import numpy as np
import joblib

# %%
sc=joblib.load('scaler.pkl')

# %%
preinput=sc.transform([[60,30,2,1,1]])
# Out:
# C:\Anaconda3.12.v\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 preinput=sc.transform([[60,30,2,1,1]])
#
# File C:\Anaconda3.12.v\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File C:\Anaconda3.12.v\Lib\site-packages\sklearn\preprocessing\_data.py:1045, in StandardScaler.transform(self, X, copy)
#    1042 check_is_fitted(self)
#    1044 copy = copy if copy is not None else self.copy
# -> 1045 X = self._validate_data(
#    1046     X,
#    1047     reset=False,
#    1048     accept_sparse="csr",
#    1049     copy=copy,
#    1050     dtype=FLOAT_DTYPES,
#    1051     force_writeable=True,
#    1052     force_all_finite="allow-nan",
#    1053 )
#    1055 if sparse.issparse(X):
#    1056     if self.with_mean:
#
# File C:\Anaconda3.12.v\Lib\site-packages\sklearn\base.py:654, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
# --> 654     self._check_n_features(X, reset=reset)
#     656 return out
#
# File C:\Anaconda3.12.v\Lib\site-packages\sklearn\base.py:443, in BaseEstimator._check_n_features(self, X, reset)
#     440     return
#     442 if n_features != self.n_features_in_:
# --> 443     raise ValueError(
#     444         f"X has {n_features} features, but {self.__class__.__name__} "
#     445         f"is expecting {self.n_features_in_} features as input."
#     446     )
#
# ValueError: X has 5 features, but StandardScaler is expecting 1 features as input.

# %%
loaded_model=pickle.load(open("finalized_model_svr.sav",'rb'))
result=loaded_model.predict(preinput)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 loaded_model=pickle.load(open("finalized_model_svr.sav",'rb'))
# ----> 2 result=loaded_model.predict(preinput)
#
# NameError: name 'preinput' is not defined

# %%
result

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput

# %%
#To eliminate this huge process we can save sc fit and reload it
